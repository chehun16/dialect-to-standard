# %% [markdown]
# <a href="https://colab.research.google.com/github/chechae/24w_audio/blob/main/kospeech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 0. Drive Mount

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1. PreProcessing - transcripts.txt 생성하기

# %%
# !pip install hydra-core --upgrade
# !pip install Levenshtein
# Out:
# ...
#   Using cached Levenshtein-0.25.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (177 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 13.2 MB/s eta 0:00:00
# ...

# %%
# !pip install -r /content/drive/MyDrive/daiv_audio/24w/kospeech/dataset/kspon/requirements.txt
# Out:
# ...
#   Using cached gluonnlp-0.10.0.tar.gz (344 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for gluonnlp: filename=gluonnlp-0.10.0-cp310-cp310-linux_x86_64.whl size=661768 sha256=4de1b15486f390e426681834f78c135a8e0caf642f06a3d9d54cb113fbbe5bfb
#   Stored in directory: /root/.cache/pip/wheels/1a/1e/0d/99f55911d90f2b95b9f7c176d5813ef3622894a4b30fde6bd3
# Successfully built gluonnlp
# ...

# %%
pwd
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/daiv_audio/24w/kospeech/dataset/kspon/
# Out:
# /content/drive/MyDrive/daiv_audio/24w/kospeech/dataset/kspon

# %%
ls -l
# Out:
# total 143122
# -rw------- 1 root root      1068 Mar 21 06:13 LICENSE
# -rw------- 1 root root      3355 Mar 21 06:13 main.py
# drwx------ 2 root root      4096 Mar 26 15:14 preprocess/
# -rw------- 1 root root       764 Apr  1 15:51 preprocess.sh
# -rw------- 1 root root      4464 Mar 21 06:13 README.md
# -rw------- 1 root root        40 Mar 21 06:13 requirements.txt
# -rw------- 1 root root 146540915 Mar 28 16:44 transcripts.txt

# %%
# 한번만 실행하고 드라이브에 저장해둘것, 다하고나서는 주석처리하기
# !chmod 777 /content/drive/MyDrive/daiv_audio/24w/kospeech/dataset/kspon/preprocess.sh
! /content/drive/MyDrive/daiv_audio/24w/kospeech/dataset/kspon/preprocess.sh
# Out:
# Pre-process KsponSpeech Dataset..
# Dataset Path : /content/drive/MyDrive/DKSR__data_share/Val/
# Vocab Destination : /content/drive/MyDrive/daiv_audio/24w/kospeech/dataset/kspon/
# Save Path : ./data
# Output-Unit : character
# Preprocess Mode : phonetic
# preprocess started..
# /content/drive/MyDrive/DKSR__data_share/Val/ValDataset/DKSR20000890
# /content/drive/MyDrive/DKSR__data_share/Val/ValDataset/DKSR20000891
# /content/drive/MyDrive/DKSR__data_share/Val/ValDataset/DKSR20000892
# /content/drive/MyDrive/DKSR__data_share/Val/ValDataset/DKSR20000893
# /content/drive/MyDrive/DKSR__data_share/Val/ValDataset/DKSR20000894
# /content/drive/MyDrive/DKSR__data_share/Val/ValDataset/DKSR20000895
# /content/drive/MyDrive/DKSR__data_share/Val/ValDataset/DKSR20000896
# /content/drive/MyDrive/DKSR__data_share/Val/ValDataset/DKSR20000897
# /content/drive/MyDrive/DKSR__data_share/Val/ValDataset/DKSR20000898
# /content/drive/MyDrive/DKSR__data_share/Val/ValDataset/DKSR20000899
# ...

# %%
ls -l
# Out:
# total 1275
# -rw------- 1 root root   11672 Apr  1 15:59 aihub_labels.csv
# -rw------- 1 root root    1068 Mar 21 06:13 LICENSE
# -rw------- 1 root root    3355 Mar 21 06:13 main.py
# drwx------ 3 root root    4096 Mar 26 15:14 preprocess/
# -rwx------ 1 root root     764 Apr  1 15:51 preprocess.sh*
# -rw------- 1 root root    4464 Mar 21 06:13 README.md
# -rw------- 1 root root      40 Mar 21 06:13 requirements.txt
# -rw------- 1 root root 1278076 Apr  1 15:59 transcripts.txt

# %% [markdown]
# ## 2. 학습

# %%
# !python /content/drive/MyDrive/daiv_audio/24w/kospeech/bin/main.py model=ds2 train=ds2_train train.dataset_path='/content/'
# Out:
# /content/drive/MyDrive/daiv_audio/24w/kospeech/bin/main.py:158: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path=os.path.join('..', "configs"), config_name="train")
# sys:1: UserWarning:
# 'audio/fbank' is validated against ConfigStore schema with the same name.
# This behavior is deprecated in Hydra 1.1 and will be removed in Hydra 1.2.
# See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/automatic_schema_matching for migration instructions.
# sys:1: UserWarning:
# 'model/ds2' is validated against ConfigStore schema with the same name.
# This behavior is deprecated in Hydra 1.1 and will be removed in Hydra 1.2.
# See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/automatic_schema_matching for migration instructions.
# sys:1: UserWarning:
# 'train/ds2_train' is validated against ConfigStore schema with the same name.
# ...
